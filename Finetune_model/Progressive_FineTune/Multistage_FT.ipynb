# %% [markdown]
# <a href="https://colab.research.google.com/github/arses-ui/Barnacles/blob/main/Finetune_model/Progressive_FineTune/Multistage_FT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size =6> Progressive FineTuning

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 50.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 117.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# <font size =4.5>Enter your own API key or download the dataset and upload it to the colab file

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your-api-key") # or you can download a zip file and upload it to the notebook
project = rf.workspace("building-1yuss").project("building-hqjen")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to building-1 in yolov8:: 100%|██████████| 19339/19339 [00:02<00:00, 7293.42it/s]

# %% [markdown]
# <FONT SIZE=4.5> CLI command for training the model. The model is specifically being trained for segmentation task.

# %%
# !yolo segment train data =/path/to/dataset/data.yaml model = yolov8m-seg.pt epochs=20 imgsz=640 batch=16
# Out:
# ...
# 100% 52.4M/52.4M [00:00<00:00, 464MB/s]
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <FONT SIZE =5> First stage of training is done. Now, I load the model using the weights from the previous training and train the model on the new dataset.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your_api_key") # or again, you can download the dataset
project = rf.workspace("testi-vq2kh").project("polygon-campur")
version = project.version(10)
dataset = version.download("yolov8")

# %%
# !yolo segment train data =/path/to/dataset/data.yaml model =your/saved/weights.pt epochs=20 imgsz=640 batch=16

# %% [markdown]
# <font size =5>Second stage of Training is done, now conducting 5-fold cross validation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <font size =4.7> In the next few cells, I save the path to my datase directory, create a pandas Dataframe that stores the label paths and number of instances of each class in respective images.

# %%
from pathlib import Path

dataset_path = Path("/content/drive/MyDrive/yolo_dataset_2")
labels = sorted(dataset_path.rglob("*labels/*.txt"))  #
print(len(labels))
# Out:
# 124

# %%
import pandas as pd

classes =["barnacle"]
cls_idx = [0]

index = [label.stem for label in labels]
labels_df = pd.DataFrame([], columns =cls_idx, index=index)

# %%
from collections import Counter

for label in labels:
    lbl_counter = Counter()

    with open(label) as lf:
        lines = lf.readlines()

    for line in lines:
        # classes for YOLO label uses integer at first position of each line
        lbl_counter[int(line.split(" ", 1)[0])] += 1

    labels_df.loc[label.stem] = lbl_counter

labels_df = labels_df.fillna(0.0)  # replace `nan` values with `0.0`
# Out:
# /tmp/ipython-input-23-1735700115.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   labels_df = labels_df.fillna(0.0)  # replace `nan` values with `0.0`

# %%
print(labels_df) #sanity check
# Out:
#                     0
# image1_patch_0000  50
# image1_patch_0001  59
# image1_patch_0002  78
# image1_patch_0003  79
# image1_patch_0004  47
# ...                ..
# image2_patch_0057   8
# image2_patch_0058   7
# image2_patch_0061   9
# image2_patch_0062  18
# image2_patch_0063  26
#
# [124 rows x 1 columns]

# %% [markdown]
# <font size =6>Splitting dataset into K folds using Scikit

# %%
# !pip install  scikit-learn

# %%
import random
from sklearn.model_selection import KFold
random.seed(0)
ksplit= 5
kf =KFold(n_splits=ksplit, shuffle=True, random_state=20)
kfolds = list(kf.split(labels_df))

# %%
folds = [f"split_{n}" for n in range(1, ksplit + 1)]
folds_df = pd.DataFrame(index=index, columns=folds)

for i, (train, val) in enumerate(kfolds, start=1):
  folds_df.loc[labels_df.iloc[train].index, f"split_{i}"] = "train"
  folds_df.loc[labels_df.iloc[val].index, f"split_{i}"] = "val"

# %%
fold_lbl_distrb = pd.DataFrame(index=folds, columns=cls_idx)

for n, (train_indices, val_indices) in enumerate(kfolds, start=1):
    train_totals = labels_df.iloc[train_indices].sum()
    val_totals = labels_df.iloc[val_indices].sum()

    # To avoid division by zero, we add a small value (1E-7) to the denominator
    ratio = val_totals / (train_totals + 1e-7)
    fold_lbl_distrb.loc[f"split_{n}"] = ratio

# %% [markdown]
# <font size = 5 >Creating directories and dataset YAML files for each split.

# %%
import datetime
import yaml

supported_extensions = [".jpg", ".jpeg", ".png"]

# Initialize an empty list to store image file paths
images = []

# Loop through supported extensions and gather image files
for ext in supported_extensions:
    images.extend(sorted((dataset_path / "images").rglob(f"*{ext}")))

# Create the necessary directories and dataset YAML files
save_path = Path(dataset_path / f"{datetime.date.today().isoformat()}_{ksplit}-Fold_Cross-val")
save_path.mkdir(parents=True, exist_ok=True)
ds_yamls = []

for split in folds_df.columns:
    # Create directories
    split_dir = save_path / split
    split_dir.mkdir(parents=True, exist_ok=True)
    (split_dir / "train" / "images").mkdir(parents=True, exist_ok=True)
    (split_dir / "train" / "labels").mkdir(parents=True, exist_ok=True)
    (split_dir / "val" / "images").mkdir(parents=True, exist_ok=True)
    (split_dir / "val" / "labels").mkdir(parents=True, exist_ok=True)

    # Create dataset YAML files
    dataset_yaml = split_dir / f"{split}_dataset.yaml"
    ds_yamls.append(dataset_yaml)

    with open(dataset_yaml, "w") as ds_y:
        yaml.safe_dump(
            {
                "path": split_dir.as_posix(),
                "train": "train",
                "val": "val",
                "names": classes,
            },
            ds_y,
        )

# %% [markdown]
# <font size =5> Copy the labels and images into the respective directory('train' or 'val') for each split.

# %%
import shutil

from tqdm import tqdm

for image, label in tqdm(zip(images, labels), total=len(images), desc="Copying files"):
    for split, k_split in folds_df.loc[image.stem].items():
        # Destination directory
        img_to_path = save_path / split / k_split / "images"
        lbl_to_path = save_path / split / k_split / "labels"

        # Copy image and label files to new directory (SamefileError if file already exists)
        shutil.copy(image, img_to_path / image.name)
        shutil.copy(label, lbl_to_path / label.name)
# Out:
# Copying files: 100%|██████████| 124/124 [00:11<00:00, 10.70it/s]

# %% [markdown]
# <font size=5.5>

# %% [markdown]
# <font size =5> Running a loop to perform 5-fold validation. Results and Weights are stored in seperate sub-directories within a larger directory.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

weights_path = "/content/drive/MyDrive/training_stage_2/best.pt"  # using small model(11.8 million parameters)

# %%
results = {}

#small number of epochs as a pretty small dataset
batch = 16
project = "Kfold_training_barnacles"
epochs = 25

for k, dataset_yaml in enumerate(ds_yamls):
    model = YOLO(weights_path, task="segment")
    results[k] = model.train(
        data=dataset_yaml, epochs=epochs, batch=batch, project=project, name=f"fold_{k + 1}"
    )  # include any additional train arguments
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
rm /content/Kfold_training_barnacles.zip

# %%
# !zip -r Kfold_training_barnacles.zip Kfold_training_barnacles/
# Out:
#   adding: Kfold_training_barnacles/ (stored 0%)
#   adding: Kfold_training_barnacles/fold_4/ (stored 0%)
#   adding: Kfold_training_barnacles/fold_4/args.yaml (deflated 52%)
#   adding: Kfold_training_barnacles/fold_4/MaskPR_curve.png (deflated 23%)
#   adding: Kfold_training_barnacles/fold_4/train_batch105.jpg (deflated 4%)
#   adding: Kfold_training_barnacles/fold_4/BoxPR_curve.png (deflated 22%)
#   adding: Kfold_training_barnacles/fold_4/train_batch1.jpg (deflated 1%)
#   adding: Kfold_training_barnacles/fold_4/confusion_matrix_normalized.png (deflated 36%)
#   adding: Kfold_training_barnacles/fold_4/labels_correlogram.jpg (deflated 38%)
#   adding: Kfold_training_barnacles/fold_4/train_batch2.jpg (deflated 1%)
#   adding: Kfold_training_barnacles/fold_4/labels.jpg (deflated 31%)
#   adding: Kfold_training_barnacles/fold_4/MaskF1_curve.png (deflated 17%)
#   adding: Kfold_training_barnacles/fold_4/BoxR_curve.png (deflated 16%)
# ...
